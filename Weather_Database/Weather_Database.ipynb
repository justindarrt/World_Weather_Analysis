# %%
# Import the dependencies.
import pandas as pd
from citipy import citipy
import numpy as np
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#cities = ["Boston","Atlanta","Miami","Hong Kong","New York","Dallas"] #Test code works on smaller city list
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": des,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lagoa
# Processing Record 2 of Set 1 | shatrovo
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | acapulco
# Processing Record 8 of Set 1 | naze
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | wagar
# Processing Record 11 of Set 1 | chegdomyn
# Processing Record 12 of Set 1 | andros town
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | ospitaletto
# Processing Record 19 of Set 1 | surt
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | port hardy
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | kakonko
# Processing Record 24 of Set 1 | lazaro cardenas
# Processing Record 25 of Set 1 | college
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | puerto lopez
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 1 | mount gambier
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | lufilufi
# Processing Record 34 of Set 1 | ilorin
# Processing Record 35 of Set 1 | denpasar
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | challapata
# Processing Record 38 of Set 1 | ponta delgada
# Processing Record 39 of Set 1 | honningsvag
# Processing Record 40 of Set 1 | sadovo
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | rawson
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | srednekolymsk
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | yumen
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | prainha
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | chumikan
# Processing Record 6 of Set 2 | morondava
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | pasighat
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | pasni
# Processing Record 15 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 2 | snyder
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | bilma
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | san carlos de bariloche
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | papara
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | dunedin
# Processing Record 27 of Set 2 | fort nelson
# Processing Record 28 of Set 2 | halifax
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | aksu
# Processing Record 31 of Set 2 | luau
# Processing Record 32 of Set 2 | shache
# Processing Record 33 of Set 2 | hay river
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | hamilton
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 2 | henties bay
# Processing Record 41 of Set 2 | brae
# Processing Record 42 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 43 of Set 2 | muyezerskiy
# Processing Record 44 of Set 2 | newport
# Processing Record 45 of Set 2 | smithers
# Processing Record 46 of Set 2 | port keats
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | saint anthony
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | tabas
# Processing Record 2 of Set 3 | port macquarie
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | necochea
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | pangai
# Processing Record 9 of Set 3 | goderich
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | abu dhabi
# Processing Record 12 of Set 3 | killybegs
# Processing Record 13 of Set 3 | sola
# Processing Record 14 of Set 3 | dalvik
# Processing Record 15 of Set 3 | yar-sale
# Processing Record 16 of Set 3 | cehegin
# Processing Record 17 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 3 | hjelset
# Processing Record 19 of Set 3 | salalah
# Processing Record 20 of Set 3 | ewa beach
# Processing Record 21 of Set 3 | pafos
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | poykovskiy
# Processing Record 24 of Set 3 | ovsyanka
# Processing Record 25 of Set 3 | we
# City not found. Skipping...
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | strezhevoy
# Processing Record 28 of Set 3 | burica
# City not found. Skipping...
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | dunayivtsi
# City not found. Skipping...
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | gornopravdinsk
# Processing Record 35 of Set 3 | hermanus
# Processing Record 36 of Set 3 | kirillov
# Processing Record 37 of Set 3 | weatherford
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | tecoanapa
# Processing Record 40 of Set 3 | amahai
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | imbituba
# Processing Record 43 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | adrar
# Processing Record 46 of Set 3 | nantucket
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | wawa
# Processing Record 49 of Set 3 | tigil
# Processing Record 50 of Set 3 | tahoua
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | stranraer
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | padang
# Processing Record 6 of Set 4 | bentiu
# Processing Record 7 of Set 4 | tailai
# Processing Record 8 of Set 4 | lima
# Processing Record 9 of Set 4 | barrow
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | tuatapere
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 4 | garca
# Processing Record 15 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 4 | umm lajj
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | ostrovnoy
# Processing Record 21 of Set 4 | vao
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | tautira
# Processing Record 24 of Set 4 | bull savanna
# Processing Record 25 of Set 4 | bud
# Processing Record 26 of Set 4 | sudova vyshnya
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | bairiki
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | barcelos
# Processing Record 32 of Set 4 | charters towers
# Processing Record 33 of Set 4 | codajas
# Processing Record 34 of Set 4 | lulea
# Processing Record 35 of Set 4 | esperance
# Processing Record 36 of Set 4 | potgietersrus
# City not found. Skipping...
# Processing Record 37 of Set 4 | rongcheng
# Processing Record 38 of Set 4 | paamiut
# Processing Record 39 of Set 4 | erzin
# Processing Record 40 of Set 4 | launceston
# Processing Record 41 of Set 4 | tiarei
# Processing Record 42 of Set 4 | kingaroy
# Processing Record 43 of Set 4 | new norfolk
# Processing Record 44 of Set 4 | ulladulla
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | tshikapa
# Processing Record 47 of Set 4 | amot
# Processing Record 48 of Set 4 | saint-augustin
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 50 of Set 4 | havelock
# Processing Record 1 of Set 5 | suket
# Processing Record 2 of Set 5 | skjervoy
# Processing Record 3 of Set 5 | kasungu
# Processing Record 4 of Set 5 | hobyo
# Processing Record 5 of Set 5 | colares
# Processing Record 6 of Set 5 | gritsovskiy
# Processing Record 7 of Set 5 | komsomolskiy
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | cayenne
# Processing Record 10 of Set 5 | gewane
# Processing Record 11 of Set 5 | kangaba
# Processing Record 12 of Set 5 | narsaq
# Processing Record 13 of Set 5 | peniche
# Processing Record 14 of Set 5 | davila
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | beringovskiy
# Processing Record 17 of Set 5 | bathsheba
# Processing Record 18 of Set 5 | hot springs
# Processing Record 19 of Set 5 | chapais
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | cockburn town
# Processing Record 22 of Set 5 | puerto penasco
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | san alberto
# Processing Record 25 of Set 5 | anchorage
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | iquitos
# Processing Record 28 of Set 5 | imperia
# Processing Record 29 of Set 5 | sakakah
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | lodja
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | jinchang
# Processing Record 34 of Set 5 | burnie
# Processing Record 35 of Set 5 | jumla
# Processing Record 36 of Set 5 | kupang
# Processing Record 37 of Set 5 | lethem
# Processing Record 38 of Set 5 | chokurdakh
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 5 | nyurba
# Processing Record 42 of Set 5 | jagdalpur
# Processing Record 43 of Set 5 | blagoyevo
# Processing Record 44 of Set 5 | pueblo bello
# Processing Record 45 of Set 5 | bonavista
# Processing Record 46 of Set 5 | fare
# Processing Record 47 of Set 5 | aklavik
# Processing Record 48 of Set 5 | te anau
# Processing Record 49 of Set 5 | mirnyy
# Processing Record 50 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | ascension
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | mount isa
# Processing Record 5 of Set 6 | camacupa
# Processing Record 6 of Set 6 | guanica
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | miandrivazo
# Processing Record 9 of Set 6 | tlucna
# Processing Record 10 of Set 6 | canhotinho
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | alexandria
# Processing Record 13 of Set 6 | prescott
# Processing Record 14 of Set 6 | san patricio
# Processing Record 15 of Set 6 | kayerkan
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | leshukonskoye
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | milkovo
# Processing Record 20 of Set 6 | shingu
# Processing Record 21 of Set 6 | elko
# Processing Record 22 of Set 6 | port elizabeth
# Processing Record 23 of Set 6 | san cristobal
# Processing Record 24 of Set 6 | sorland
# Processing Record 25 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 6 | talnakh
# Processing Record 27 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 28 of Set 6 | mundi
# Processing Record 29 of Set 6 | east london
# Processing Record 30 of Set 6 | mumford
# Processing Record 31 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 6 | sheregesh
# Processing Record 33 of Set 6 | george
# Processing Record 34 of Set 6 | uusikaupunki
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | codrington
# Processing Record 37 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 38 of Set 6 | phrai bung
# City not found. Skipping...
# Processing Record 39 of Set 6 | maryborough
# Processing Record 40 of Set 6 | jacqueville
# Processing Record 41 of Set 6 | looc
# Processing Record 42 of Set 6 | kirkuk
# Processing Record 43 of Set 6 | charlestown
# Processing Record 44 of Set 6 | itarema
# Processing Record 45 of Set 6 | mokshan
# Processing Record 46 of Set 6 | kuhdasht
# Processing Record 47 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 49 of Set 6 | pitimbu
# Processing Record 50 of Set 6 | ipilan
# Processing Record 1 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 7 | sun valley
# Processing Record 3 of Set 7 | rayong
# Processing Record 4 of Set 7 | pevek
# Processing Record 5 of Set 7 | fairview
# Processing Record 6 of Set 7 | akodia
# Processing Record 7 of Set 7 | pedro ii
# Processing Record 8 of Set 7 | tarata
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | beloha
# Processing Record 11 of Set 7 | fukue
# Processing Record 12 of Set 7 | cururupu
# Processing Record 13 of Set 7 | rundu
# Processing Record 14 of Set 7 | kalakamati
# Processing Record 15 of Set 7 | lewiston
# Processing Record 16 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | georgetown
# Processing Record 19 of Set 7 | avera
# Processing Record 20 of Set 7 | slave lake
# Processing Record 21 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 7 | alpena
# Processing Record 23 of Set 7 | bogalusa
# Processing Record 24 of Set 7 | zuenoula
# Processing Record 25 of Set 7 | bilibino
# Processing Record 26 of Set 7 | alice springs
# Processing Record 27 of Set 7 | tampere
# Processing Record 28 of Set 7 | svetlogorsk
# Processing Record 29 of Set 7 | voznesenye
# Processing Record 30 of Set 7 | kintampo
# Processing Record 31 of Set 7 | pacific grove
# Processing Record 32 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 7 | nouakchott
# Processing Record 34 of Set 7 | berbera
# Processing Record 35 of Set 7 | palu
# Processing Record 36 of Set 7 | san mateo del mar
# Processing Record 37 of Set 7 | griffith
# Processing Record 38 of Set 7 | lavrentiya
# Processing Record 39 of Set 7 | yashkul
# Processing Record 40 of Set 7 | nikolskoye
# Processing Record 41 of Set 7 | yefimovskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | vestmannaeyjar
# Processing Record 43 of Set 7 | berlevag
# Processing Record 44 of Set 7 | camana
# Processing Record 45 of Set 7 | mantua
# Processing Record 46 of Set 7 | urdoma
# Processing Record 47 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 48 of Set 7 | tromso
# Processing Record 49 of Set 7 | broome
# Processing Record 50 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 8 | vanavara
# Processing Record 2 of Set 8 | palembang
# Processing Record 3 of Set 8 | camacha
# Processing Record 4 of Set 8 | la tuque
# Processing Record 5 of Set 8 | bereda
# Processing Record 6 of Set 8 | boa vista
# Processing Record 7 of Set 8 | najran
# Processing Record 8 of Set 8 | saint-francois
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | male
# Processing Record 12 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 8 | dingle
# Processing Record 14 of Set 8 | port hedland
# Processing Record 15 of Set 8 | douglas
# Processing Record 16 of Set 8 | coruripe
# Processing Record 17 of Set 8 | eenhana
# Processing Record 18 of Set 8 | goedereede
# Processing Record 19 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 8 | nishihara
# Processing Record 21 of Set 8 | kilrush
# Processing Record 22 of Set 8 | arlit
# Processing Record 23 of Set 8 | balikpapan
# Processing Record 24 of Set 8 | atkinson
# Processing Record 25 of Set 8 | simpang
# Processing Record 26 of Set 8 | monte alegre
# Processing Record 27 of Set 8 | alofi
# Processing Record 28 of Set 8 | jackson
# Processing Record 29 of Set 8 | kahului
# Processing Record 30 of Set 8 | avondale
# Processing Record 31 of Set 8 | batticaloa
# Processing Record 32 of Set 8 | katsuura
# Processing Record 33 of Set 8 | thompson
# Processing Record 34 of Set 8 | tambura
# Processing Record 35 of Set 8 | sao joao da barra
# Processing Record 36 of Set 8 | meulaboh
# Processing Record 37 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 38 of Set 8 | tripoli
# Processing Record 39 of Set 8 | jagannathpur
# Processing Record 40 of Set 8 | neiafu
# Processing Record 41 of Set 8 | vuktyl
# Processing Record 42 of Set 8 | zhezkazgan
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | neyshabur
# Processing Record 45 of Set 8 | synya
# Processing Record 46 of Set 8 | rochegda
# Processing Record 47 of Set 8 | xinzhou
# Processing Record 48 of Set 8 | tahe
# Processing Record 49 of Set 8 | buchanan
# Processing Record 50 of Set 8 | lakatoro
# Processing Record 1 of Set 9 | bermejo
# Processing Record 2 of Set 9 | kavieng
# Processing Record 3 of Set 9 | lompoc
# Processing Record 4 of Set 9 | ariquemes
# Processing Record 5 of Set 9 | znamenskoye
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | prachuap khiri khan
# Processing Record 8 of Set 9 | kropotkin
# Processing Record 9 of Set 9 | morehead
# Processing Record 10 of Set 9 | luanda
# Processing Record 11 of Set 9 | visby
# Processing Record 12 of Set 9 | sistranda
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | villa maria
# Processing Record 15 of Set 9 | vostok
# Processing Record 16 of Set 9 | santa maria
# Processing Record 17 of Set 9 | baghdad
# Processing Record 18 of Set 9 | gat
# Processing Record 19 of Set 9 | bayreuth
# Processing Record 20 of Set 9 | santa fe
# Processing Record 21 of Set 9 | riyadh
# Processing Record 22 of Set 9 | porto walter
# Processing Record 23 of Set 9 | almaznyy
# Processing Record 24 of Set 9 | aswan
# Processing Record 25 of Set 9 | sidi qasim
# City not found. Skipping...
# Processing Record 26 of Set 9 | vila franca do campo
# Processing Record 27 of Set 9 | masallatah
# Processing Record 28 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 9 | fatezh
# Processing Record 30 of Set 9 | namatanai
# Processing Record 31 of Set 9 | weinfelden
# Processing Record 32 of Set 9 | sulecin
# Processing Record 33 of Set 9 | kaitong
# Processing Record 34 of Set 9 | nouadhibou
# Processing Record 35 of Set 9 | mendi
# Processing Record 36 of Set 9 | abu zabad
# Processing Record 37 of Set 9 | urumqi
# Processing Record 38 of Set 9 | smidovich
# Processing Record 39 of Set 9 | redondo
# Processing Record 40 of Set 9 | tirlyanskiy
# Processing Record 41 of Set 9 | olafsvik
# Processing Record 42 of Set 9 | kaihua
# Processing Record 43 of Set 9 | dong hoi
# Processing Record 44 of Set 9 | srikakulam
# Processing Record 45 of Set 9 | fairbanks
# Processing Record 46 of Set 9 | hami
# Processing Record 47 of Set 9 | tutoia
# Processing Record 48 of Set 9 | panalingaan
# Processing Record 49 of Set 9 | chibombo
# Processing Record 50 of Set 9 | los banos
# Processing Record 1 of Set 10 | tougue
# Processing Record 2 of Set 10 | sao filipe
# Processing Record 3 of Set 10 | kwinana
# Processing Record 4 of Set 10 | urengoy
# Processing Record 5 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 10 | san francisco del mar
# Processing Record 7 of Set 10 | pangnirtung
# Processing Record 8 of Set 10 | harper
# Processing Record 9 of Set 10 | toora-khem
# Processing Record 10 of Set 10 | asau
# Processing Record 11 of Set 10 | poum
# Processing Record 12 of Set 10 | port blair
# Processing Record 13 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 10 | kenai
# Processing Record 15 of Set 10 | ankang
# Processing Record 16 of Set 10 | atbasar
# Processing Record 17 of Set 10 | senneterre
# Processing Record 18 of Set 10 | mecca
# Processing Record 19 of Set 10 | mezen
# Processing Record 20 of Set 10 | kinablangan
# Processing Record 21 of Set 10 | cascais
# Processing Record 22 of Set 10 | bousso
# Processing Record 23 of Set 10 | partizanskoye
# Processing Record 24 of Set 10 | taldan
# Processing Record 25 of Set 10 | alta floresta
# Processing Record 26 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 10 | hit
# Processing Record 28 of Set 10 | dogbo
# Processing Record 29 of Set 10 | blagoveshchenka
# Processing Record 30 of Set 10 | vallenar
# Processing Record 31 of Set 10 | waipawa
# Processing Record 32 of Set 10 | zenzeli
# Processing Record 33 of Set 10 | tawzar
# City not found. Skipping...
# Processing Record 34 of Set 10 | liverpool
# Processing Record 35 of Set 10 | faizpur
# Processing Record 36 of Set 10 | brownsville
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 10 | zabol
# Processing Record 40 of Set 10 | dzhebariki-khaya
# Processing Record 41 of Set 10 | jacmel
# Processing Record 42 of Set 10 | qianan
# Processing Record 43 of Set 10 | barranca
# Processing Record 44 of Set 10 | carros
# Processing Record 45 of Set 10 | machali
# Processing Record 46 of Set 10 | haimen
# Processing Record 47 of Set 10 | coromandel
# Processing Record 48 of Set 10 | husavik
# Processing Record 49 of Set 10 | kangaatsiaq
# Processing Record 50 of Set 10 | alanya
# Processing Record 1 of Set 11 | kohat
# Processing Record 2 of Set 11 | ipatovo
# Processing Record 3 of Set 11 | galveston
# Processing Record 4 of Set 11 | cabo san lucas
# Processing Record 5 of Set 11 | namibe
# Processing Record 6 of Set 11 | rengali
# Processing Record 7 of Set 11 | pahrump
# Processing Record 8 of Set 11 | hirara
# Processing Record 9 of Set 11 | ketchenery
# City not found. Skipping...
# Processing Record 10 of Set 11 | linhares
# Processing Record 11 of Set 11 | bima
# Processing Record 12 of Set 11 | marzuq
# Processing Record 13 of Set 11 | tessalit
# Processing Record 14 of Set 11 | turukhansk
# Processing Record 15 of Set 11 | muroto
# Processing Record 16 of Set 11 | la palma
# Processing Record 17 of Set 11 | booue
# Processing Record 18 of Set 11 | santa lucia
# Processing Record 19 of Set 11 | torbay
# Processing Record 20 of Set 11 | sur
# Processing Record 21 of Set 11 | rockland
# Processing Record 22 of Set 11 | domoni
# Processing Record 23 of Set 11 | tadine
# Processing Record 24 of Set 11 | gizo
# Processing Record 25 of Set 11 | mnogovershinnyy
# Processing Record 26 of Set 11 | panacan
# Processing Record 27 of Set 11 | gawler
# Processing Record 28 of Set 11 | kloulklubed
# Processing Record 29 of Set 11 | makat
# Processing Record 30 of Set 11 | sept-iles
# Processing Record 31 of Set 11 | belaya gora
# Processing Record 32 of Set 11 | neuquen
# Processing Record 33 of Set 11 | aborlan
# Processing Record 34 of Set 11 | qurayyat
# Processing Record 35 of Set 11 | altamont
# Processing Record 36 of Set 11 | kiruna
# Processing Record 37 of Set 11 | jejuri
# Processing Record 38 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 11 | penzance
# Processing Record 40 of Set 11 | sangin
# Processing Record 41 of Set 11 | zunyi
# Processing Record 42 of Set 11 | pangody
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 11 | kirakira
# Processing Record 46 of Set 11 | sao paulo de olivenca
# Processing Record 47 of Set 11 | bolshaya murta
# City not found. Skipping...
# Processing Record 48 of Set 11 | the valley
# Processing Record 49 of Set 11 | sao desiderio
# Processing Record 50 of Set 11 | san juan
# Processing Record 1 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 12 | beitbridge
# Processing Record 3 of Set 12 | ryotsu
# Processing Record 4 of Set 12 | wuwei
# Processing Record 5 of Set 12 | makaha
# Processing Record 6 of Set 12 | yavatmal
# Processing Record 7 of Set 12 | erdaojiang
# Processing Record 8 of Set 12 | leh
# Processing Record 9 of Set 12 | quatre cocos
# Processing Record 10 of Set 12 | hokitika
# Processing Record 11 of Set 12 | souillac
# Processing Record 12 of Set 12 | mocuba
# Processing Record 13 of Set 12 | prince rupert
# Processing Record 14 of Set 12 | nola
# Processing Record 15 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 12 | dzaoudzi
# Processing Record 17 of Set 12 | rapid valley
# Processing Record 18 of Set 12 | agulu
# Processing Record 19 of Set 12 | lishu
# Processing Record 20 of Set 12 | kendari
# Processing Record 21 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 12 | yacuiba
# Processing Record 23 of Set 12 | omsukchan
# Processing Record 24 of Set 12 | san javier
# Processing Record 25 of Set 12 | ust-kuyga
# Processing Record 26 of Set 12 | pochutla
# Processing Record 27 of Set 12 | havoysund
# Processing Record 28 of Set 12 | harlingen
# Processing Record 29 of Set 12 | walvis bay
# Processing Record 30 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 12 | tucupita
# Processing Record 32 of Set 12 | saint-pierre
# Processing Record 33 of Set 12 | tokur
# Processing Record 34 of Set 12 | banda aceh
# Processing Record 35 of Set 12 | lieto
# Processing Record 36 of Set 12 | matsuura
# Processing Record 37 of Set 12 | santa cruz
# Processing Record 38 of Set 12 | tiksi
# Processing Record 39 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 12 | bemidji
# Processing Record 41 of Set 12 | noshiro
# Processing Record 42 of Set 12 | glenwood springs
# Processing Record 43 of Set 12 | chimore
# Processing Record 44 of Set 12 | san rafael
# Processing Record 45 of Set 12 | loksa
# Processing Record 46 of Set 12 | celestun
# Processing Record 47 of Set 12 | athens
# Processing Record 48 of Set 12 | yabelo
# Processing Record 49 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 12 | christchurch
# Processing Record 1 of Set 13 | roebourne
# Processing Record 2 of Set 13 | suarez
# Processing Record 3 of Set 13 | medzilaborce
# Processing Record 4 of Set 13 | lampazos de naranjo
# Processing Record 5 of Set 13 | kununurra
# Processing Record 6 of Set 13 | florida ridge
# Processing Record 7 of Set 13 | hofn
# Processing Record 8 of Set 13 | galesong
# Processing Record 9 of Set 13 | yinchuan
# Processing Record 10 of Set 13 | ardakan
# Processing Record 11 of Set 13 | lengshuitan
# Processing Record 12 of Set 13 | zhigansk
# Processing Record 13 of Set 13 | san cosme y damian
# Processing Record 14 of Set 13 | buin
# Processing Record 15 of Set 13 | gigmoto
# Processing Record 16 of Set 13 | iracoubo
# Processing Record 17 of Set 13 | taltal
# Processing Record 18 of Set 13 | hambantota
# Processing Record 19 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 13 | mubi
# Processing Record 21 of Set 13 | havre
# Processing Record 22 of Set 13 | marsa matruh
# Processing Record 23 of Set 13 | rio grande
# Processing Record 24 of Set 13 | nandura
# Processing Record 25 of Set 13 | shkotovo-26
# City not found. Skipping...
# Processing Record 26 of Set 13 | pingliang
# Processing Record 27 of Set 13 | challans
# Processing Record 28 of Set 13 | portland
# Processing Record 29 of Set 13 | honiara
# Processing Record 30 of Set 13 | juneau
# Processing Record 31 of Set 13 | shaoyang
# Processing Record 32 of Set 13 | salinas
# Processing Record 33 of Set 13 | comodoro rivadavia
# Processing Record 34 of Set 13 | dengfeng
# Processing Record 35 of Set 13 | isangel
# Processing Record 36 of Set 13 | zhuanghe
# Processing Record 37 of Set 13 | manubul
# Processing Record 38 of Set 13 | awbari
# Processing Record 39 of Set 13 | trapani
# Processing Record 40 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 13 | buturlinovka
# Processing Record 42 of Set 13 | teya
# Processing Record 43 of Set 13 | hualmay
# Processing Record 44 of Set 13 | belonia
# Processing Record 45 of Set 13 | cap malheureux
# Processing Record 46 of Set 13 | lasa
# Processing Record 47 of Set 13 | grand-santi
# Processing Record 48 of Set 13 | maldonado
# Processing Record 49 of Set 13 | xuanzhou
# Processing Record 50 of Set 13 | shenzhen
# Processing Record 1 of Set 14 | lensk
# Processing Record 2 of Set 14 | lake havasu city
# Processing Record 3 of Set 14 | bulalacao
# Processing Record 4 of Set 14 | simbahan
# Processing Record 5 of Set 14 | russell
# Processing Record 6 of Set 14 | oyama
# Processing Record 7 of Set 14 | samarai
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | fortuna
# Processing Record 10 of Set 14 | raton
# Processing Record 11 of Set 14 | roma
# Processing Record 12 of Set 14 | tiznit
# Processing Record 13 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 14 of Set 14 | faya
# Processing Record 15 of Set 14 | muddebihal
# Processing Record 16 of Set 14 | anadyr
# Processing Record 17 of Set 14 | yabrud
# Processing Record 18 of Set 14 | canon city
# Processing Record 19 of Set 14 | port lincoln
# Processing Record 20 of Set 14 | nizwa
# Processing Record 21 of Set 14 | santa isabel
# Processing Record 22 of Set 14 | paso de los toros
# Processing Record 23 of Set 14 | monchegorsk
# Processing Record 24 of Set 14 | plattsburgh
# Processing Record 25 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 26 of Set 14 | annau
# Processing Record 27 of Set 14 | zeya
# Processing Record 28 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 29 of Set 14 | kiama
# Processing Record 30 of Set 14 | concordia
# Processing Record 31 of Set 14 | iskateley
# Processing Record 32 of Set 14 | monrovia
# Processing Record 33 of Set 14 | buala
# Processing Record 34 of Set 14 | kirriemuir
# Processing Record 35 of Set 14 | bosaso
# Processing Record 36 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 37 of Set 14 | martapura
# Processing Record 38 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 14 | narrabri
# Processing Record 40 of Set 14 | banjar
# Processing Record 41 of Set 14 | alberdi
# Processing Record 42 of Set 14 | moron
# Processing Record 43 of Set 14 | kulhudhuffushi
# Processing Record 44 of Set 14 | kualakapuas
# Processing Record 45 of Set 14 | homer
# Processing Record 46 of Set 14 | labuhan
# Processing Record 47 of Set 14 | khuzdar
# Processing Record 48 of Set 14 | oranjemund
# Processing Record 49 of Set 14 | sladkovicovo
# Processing Record 50 of Set 14 | barinas
# Processing Record 1 of Set 15 | haines junction
# Processing Record 2 of Set 15 | solnechnyy
# Processing Record 3 of Set 15 | savannah bight
# Processing Record 4 of Set 15 | bang len
# Processing Record 5 of Set 15 | tucumcari
# Processing Record 6 of Set 15 | bara
# Processing Record 7 of Set 15 | tahta
# Processing Record 8 of Set 15 | kruisfontein
# Processing Record 9 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 10 of Set 15 | gorontalo
# Processing Record 11 of Set 15 | seoul
# Processing Record 12 of Set 15 | progreso
# Processing Record 13 of Set 15 | dahuk
# Processing Record 14 of Set 15 | rosarito
# Processing Record 15 of Set 15 | half moon bay
# Processing Record 16 of Set 15 | wicklow
# Processing Record 17 of Set 15 | deputatskiy
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | aquin
# Processing Record 20 of Set 15 | smiltene
# Processing Record 21 of Set 15 | doha
# Processing Record 22 of Set 15 | shambu
# Processing Record 23 of Set 15 | la cruz
# Processing Record 24 of Set 15 | gambiran
# Processing Record 25 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 15 | rio cuarto
# Processing Record 27 of Set 15 | ulaangom
# Processing Record 28 of Set 15 | aripuana
# Processing Record 29 of Set 15 | sogne
# Processing Record 30 of Set 15 | wuchang
# Processing Record 31 of Set 15 | jalalpur
# Processing Record 32 of Set 15 | aqtobe
# Processing Record 33 of Set 15 | danli
# Processing Record 34 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 15 | xuddur
# Processing Record 36 of Set 15 | erfurt
# Processing Record 37 of Set 15 | coahuayana
# Processing Record 38 of Set 15 | igrim
# Processing Record 39 of Set 15 | qarchi gak
# Processing Record 40 of Set 15 | lorengau
# Processing Record 41 of Set 15 | ellensburg
# Processing Record 42 of Set 15 | batagay-alyta
# Processing Record 43 of Set 15 | burgeo
# Processing Record 44 of Set 15 | kudat
# Processing Record 45 of Set 15 | westport
# Processing Record 46 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 15 | barra patuca
# Processing Record 48 of Set 15 | moranbah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Lagoa  39.0500  -27.9833     63.86        92          73        3.04
# 1     Shatrovo  56.5167   64.6333     51.03        89         100       12.12
# 2    Cape Town -33.9258   18.4232     62.28        71          20        6.91
# 3  Port Alfred -33.5906   26.8910     59.18        88          78        1.99
# 4     Acapulco  16.8634  -99.8901     82.22        65          40        4.61
# 5         Naze  28.3667  129.4833     67.12        84          67       10.96
# 6      Rikitea -23.1203 -134.9692     74.71        74          11        6.33
# 7        Wagar  16.1525   36.2032    103.80        13          59        2.86
# 8    Chegdomyn  51.1167  133.0167     43.03        97          99        2.08
# 9  Andros Town  24.7000  -77.7667     85.96        80          75       17.47
#
#   Country Current Description                 Date
# 0      PT       broken clouds  2022-05-21 16:26:11
# 1      RU     overcast clouds  2022-05-21 16:26:11
# 2      ZA          few clouds  2022-05-21 16:22:38
# 3      ZA       broken clouds  2022-05-21 16:26:12
# 4      MX    scattered clouds  2022-05-21 16:26:06
# 5      JP       broken clouds  2022-05-21 16:26:12
# 6      PF          few clouds  2022-05-21 16:26:12
# 7      SD       broken clouds  2022-05-21 16:26:13
# 8      RU     overcast clouds  2022-05-21 16:26:13
# 9      BS       broken clouds  2022-05-21 16:26:13

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/justi/Class/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
